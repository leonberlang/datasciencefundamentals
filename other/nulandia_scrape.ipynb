# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
# Use the requests library to get the overview page and feed the HTML of that page to the BeautifulSoup library.
req = requests.get("https://www.nulandia.nl/287/team-informatie/?sznid=4")
html = req.text
soup = BeautifulSoup(html, "lxml")

# %%
# Use the select method of BeautifulSoup to make a list of the items containing the names, whether that are table rows, list elements, divs, etcetera.
names = soup.select(".well.well-sm.clearfix a h4")
links = soup.select(".well.well-sm.clearfix a")
images =  soup.select('img.img-thumbnail')

# %%
player_names = []
player_links = []
player_images = []

# Loop through that list and get the basic information out of the rows and append that as a dict to a list. You should at least get the person's name and the link to their 'detail' page. Optionally, limit this list to the first 25 people on the page.
# Also doing some data cleaning + Changing the basic default image to "no_profile_picture"

for name in names:
    name = name.get_text()
    player_names.append(name)
    
for link in links:
    path = link['href']
    url = f'http://nulandia.nl{path}'
    if url not in player_links: #stopping duplicate entries
        player_links.append(url)

for image in images:
    image_url = image['src']
    if image_url == "https://cache.voetbalassist.nl/Data/Nulandia/Modules/ClubManagement/Front/Persoon/Standaard/Thumb/0.jpg?ticks=636174726621921994&w=60&h=80&crop=auto&quality=80":
        image_url = "no_profile_picture"
    player_images.append(image_url)

# %%
# Convert the list with dicts to a Pandas dataframe, save it to a CSV file and display the dataframe in the Notebook.
basic_player_info = []

for name in player_names:
    list_location = player_names.index(name)
    info = {
        "name": player_names[list_location],
        "link": player_links[list_location],
        "image": player_images[list_location]
    }
    basic_player_info.append(info)

basic_df = pd.DataFrame(basic_player_info)
basic_df.to_csv("basic_nulandia.csv")
basic_df
# Out:
#                                                 image  \
# 0   https://cache.voetbalassist.nl/Data/Nulandia/M...
# 1   https://cache.voetbalassist.nl/Data/Nulandia/M...
# 2   https://cache.voetbalassist.nl/Data/Nulandia/M...
# 3                                  no_profile_picture
# 4   https://cache.voetbalassist.nl/Data/Nulandia/M...
# 5   https://cache.voetbalassist.nl/Data/Nulandia/M...
# 6   https://cache.voetbalassist.nl/Data/Nulandia/M...
# 7   https://cache.voetbalassist.nl/Data/Nulandia/M...
# 8   https://cache.voetbalassist.nl/Data/Nulandia/M...
# 9   https://cache.voetbalassist.nl/Data/Nulandia/M...
# 10  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 11  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 12                                 no_profile_picture
# 13                                 no_profile_picture
# 14  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 15  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 16  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 17  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 18  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 19                                 no_profile_picture
# 20  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 21  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 22  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 23  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 24                                 no_profile_picture
# 25  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 26  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 27  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 28  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 29  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 30                                 no_profile_picture
# 31  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 32  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 33  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 34  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 35  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 36  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 37  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 38                                 no_profile_picture
# 39  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 40  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 41  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 42  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 43  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 44  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 45  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 46  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 47  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 48  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 49                                 no_profile_picture
# 50                                 no_profile_picture
# 51                                 no_profile_picture
# 52                                 no_profile_picture
# 53  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 54                                 no_profile_picture
#
#                                                  link                  name
# 0      http://nulandia.nl/488/33/sander-arts/profiel/           Sander Arts
# 1   http://nulandia.nl/488/43/stan-van-bergen/prof...       Stan van Bergen
# 2   http://nulandia.nl/488/42/stef-van-bergen/prof...       Stef van Bergen
# 3    http://nulandia.nl/488/54/tim-vd-biezen/profiel/        Tim vd. Biezen
# 4   http://nulandia.nl/488/104/martijn-coelen/prof...        Martijn Coelen
# 5   http://nulandia.nl/488/127/luuk-van-de-doelen/...    Luuk van de Doelen
# 6   http://nulandia.nl/488/146/stijn-van-der-donk/...    Stijn van der Donk
# 7   http://nulandia.nl/488/150/thijs-van-druenen/p...     Thijs van Druenen
# 8   http://nulandia.nl/488/152/patrick-van-de-elze...  Patrick van de Elzen
# 9   http://nulandia.nl/488/189/stef-de-groot/profiel/         Stef de Groot
# 10  http://nulandia.nl/488/199/tomas-habraken/prof...        Tomas Habraken
# 51  http://nulandia.nl/488/489/erik-van-der-sangen...   Erik van der Sangen
# 52  http://nulandia.nl/488/106/willie-coelen/profiel/         Willie Coelen
# 53   http://nulandia.nl/488/351/nic-vd-leest/profiel/          Nic vd Leest
# 54  http://nulandia.nl/488/752/marc-van-delft/prof...        Marc van Delft

# %%
# Loop through the list again, fetch the user detail page with requests, parse that using BeautifulSoup and add user detail information to the list.
all_players = []

for player in basic_player_info:
    link = player['link']
    req = requests.get(link)
    html = req.text
    soup = BeautifulSoup(html, "lxml")
    birthday = soup.select(".col-sm-9")[1].get_text()
    status = soup.select(".pull-left li")[0].get_text().strip()
    team = status.split(",")[0].strip()
    team_role = status.split(",")
    
    # Dealing with exceptions when the profile page is different from normal
    if len(team_role) > 1:
        team_role = team_role[1].strip()
    else:
        team_role = team_role[0].strip()
    
    player["birthday"] = birthday
    player["team"] = team
    player["team_role"] = team_role

# %%
# Convert the ‘expanded’ list with dicts to a Pandas dataframe and save that to a CSV file, and display the dataframe in the Notebook.
df = pd.DataFrame(basic_player_info)
df
# Out:
#         birthday                                              image  \
# 0         5 juni  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 1     21 oktober  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 2        13 juni  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 3        31 juli                                 no_profile_picture
# 4       15 april  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 5     8 februari  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 6         24 mei  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 7          2 mei  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 8         26 mei  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 9     20 oktober  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 10       17 juli  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 11      15 maart  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 12      15 april                                 no_profile_picture
# 13        6 juli                                 no_profile_picture
# 14   14 december  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 15    28 oktober  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 16     4 oktober  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 17   26 december  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 18   22 februari  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 19      19 april                                 no_profile_picture
# 20   24 december  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 21      29 april  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 22  20 september  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 23       26 juni  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 24        20 mei                                 no_profile_picture
# 25       16 juni  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 26     7 januari  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 27       4 maart  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 28   17 augustus  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 29       24 juni  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 30    10 januari                                 no_profile_picture
# 31       29 juni  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 32      12 maart  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 33      16 april  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 34      29 april  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 35        2 juni  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 36   26 november  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 37        3 juni  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 38   1 september                                 no_profile_picture
# 39   31 augustus  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 40    15 oktober  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 41       15 juli  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 42   25 februari  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 43      30 april  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 44        4 juli  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 45       25 juli  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 46   22 december  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 47      26 april  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 48      17 maart  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 49       18 juli                                 no_profile_picture
# 50   27 augustus                                 no_profile_picture
# 51   27 augustus                                 no_profile_picture
# 52       30 juli                                 no_profile_picture
# 53     4 januari  https://cache.voetbalassist.nl/Data/Nulandia/M...
# 54    8 december                                 no_profile_picture
#
#                                                  link                  name  \
# 0      http://nulandia.nl/488/33/sander-arts/profiel/           Sander Arts
# 1   http://nulandia.nl/488/43/stan-van-bergen/prof...       Stan van Bergen
# 2   http://nulandia.nl/488/42/stef-van-bergen/prof...       Stef van Bergen
# 3    http://nulandia.nl/488/54/tim-vd-biezen/profiel/        Tim vd. Biezen
# 4   http://nulandia.nl/488/104/martijn-coelen/prof...        Martijn Coelen
# 5   http://nulandia.nl/488/127/luuk-van-de-doelen/...    Luuk van de Doelen
# 6   http://nulandia.nl/488/146/stijn-van-der-donk/...    Stijn van der Donk
# 7   http://nulandia.nl/488/150/thijs-van-druenen/p...     Thijs van Druenen
# 8   http://nulandia.nl/488/152/patrick-van-de-elze...  Patrick van de Elzen
# 9   http://nulandia.nl/488/189/stef-de-groot/profiel/         Stef de Groot
# 51  http://nulandia.nl/488/489/erik-van-der-sangen...   Erik van der Sangen
# 52  http://nulandia.nl/488/106/willie-coelen/profiel/         Willie Coelen
# 53   http://nulandia.nl/488/351/nic-vd-leest/profiel/          Nic vd Leest
# 54  http://nulandia.nl/488/752/marc-van-delft/prof...        Marc van Delft
#
#                            team                      team_role
# 0              Nulandia 1 (zon)                     Teamspeler
# 1              Nulandia 1 (zon)                     Teamspeler
# 2              Nulandia 1 (zon)                     Teamspeler
# 3              Nulandia 1 (zon)                     Teamspeler
# 4              Nulandia 1 (zon)                     Teamspeler
# 5              Nulandia 1 (zon)                     Teamspeler
# 6              Nulandia 1 (zon)                     Teamspeler
# 7              Nulandia 1 (zon)                     Teamspeler
# 8              Nulandia 1 (zon)                     Teamspeler
# 9              Nulandia 1 (zon)                     Teamspeler
# 10             Nulandia 1 (zon)                     Teamspeler
# 11             Nulandia 1 (zon)                     Teamspeler
# 12             Nulandia 1 (zon)                     Teamspeler
# 13             Nulandia 1 (zon)                     Teamspeler
# 14             Nulandia 1 (zon)                     Teamspeler
# 15             Nulandia 1 (zon)                     Teamspeler
# 16             Nulandia 1 (zon)                     Teamspeler
# 17             Nulandia 1 (zon)                     Teamspeler
# 18             Nulandia 1 (zon)                     Teamspeler
# 19             Nulandia 1 (zon)                     Teamspeler
# 20             Nulandia 1 (zon)                     Teamspeler
# 21             Nulandia 1 (zon)                     Teamspeler
# 22             Nulandia 1 (zon)                     Teamspeler
# 23             Nulandia 1 (zon)                     Teamspeler
# 24             Nulandia 1 (zon)                     Teamspeler
# 25             Nulandia 1 (zon)                     Teamspeler
# 26             Nulandia 1 (zon)                     Teamspeler
# 27             Nulandia 1 (zon)                     Teamspeler
# 28             Nulandia 1 (zon)                     Teamspeler
# 29             Nulandia 1 (zon)                     Teamspeler
# 30             Nulandia 1 (zon)                     Teamspeler
# 31             Nulandia 1 (zon)                     Teamspeler
# 32             Nulandia 1 (zon)                     Teamspeler
# 33             Nulandia 1 (zon)                     Teamspeler
# 34             Nulandia 1 (zon)                     Teamspeler
# 35             Nulandia 1 (zon)                     Teamspeler
# 36             Nulandia 1 (zon)                     Teamspeler
# 37             Nulandia 1 (zon)                     Teamspeler
# 38             Nulandia 1 (zon)                     Teamspeler
# 39             Nulandia 1 (zon)                     Teamspeler
# 40             Nulandia 1 (zon)                     Teamspeler
# 41             Nulandia 1 (zon)                     Teamspeler
# 42             Nulandia 1 (zon)                     Teamspeler
# 43             Nulandia 1 (zon)                     Teamspeler
# 44             Nulandia 1 (zon)                     Teamspeler
# 45             Nulandia 1 (zon)                     Teamspeler
# 46             Nulandia 1 (zon)                     Teamspeler
# 47             Nulandia 1 (zon)                     Teamspeler
# 48             Nulandia 1 (zon)                     Teamspeler
# 49             Nulandia 1 (zon)                      Verzorger
# 50          Ledenadministrateur            Ledenadministrateur
# 51             Nulandia 1 (zon)                    Teammanager
# 52             Nulandia 1 (zon)  Assistentscheidsrechter(club)
# 53  Clubscheidsrechter Senioren    Clubscheidsrechter Senioren
# 54             Nulandia 1 (zon)                  Trainer/coach

# %%
df.to_csv("nulandia.csv")
